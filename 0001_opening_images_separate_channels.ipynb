# %% [markdown]
# Video-tutorial in the  Youtube channel BioPrograma  https://www.youtube.com/channel/UCbJAU7N9FYvwkdgSwD_1S4Q

# %%
#!pip install scikit-image
#!pip install matplotlib

# %%
from skimage.io import (imread, imshow, imsave)
import matplotlib.pyplot as plt
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\bruni\OneDrive\Documents

# %%
os.chdir('C:/Users/bruni/OneDrive/Documents/imajiboia')
print(os.getcwd())
# Out:
# C:\Users\bruni\OneDrive\Documents\imajiboia

# %%
# the "Rat_Hippocampal_Neuron.tif" file can be donwloaded here https://imagej.net/ij/images/
image_file = "Rat_Hippocampal_Neuron.tif"

# %%
img = imread(image_file)

# %%
img.shape
# Out:
# (5, 512, 512)

# %%
imshow(img[4,:,:], cmap= 'gray_r')

# %%
figs, axs = plt.subplots(2,3, figsize=(20,20))
axs[0, 0].imshow(img[0,:,:], cmap='gray', vmin=1000, vmax= 3000)
axs[0, 1].imshow(img[1,:,:], cmap= 'gray', vmin=1000, vmax= 4000)
axs[0, 2].imshow(img[2,:,:], cmap= 'gray', vmin=1000, vmax= 2000)
axs[1, 0].imshow(img[3,:,:], cmap= 'gray', vmin=1000, vmax= 2000)
axs[1, 1].imshow(img[4,:,:], cmap= 'gray')
figs.delaxes(axs[1, 2])

# %%
# !mkdir single_channel

# %%
cn1 =img[0, :, :]
cn1.shape
#imsave(channel1, 'channel1.tiff')
# Out:
# (512, 512)

# %%
imsave('single_channel/channel1.tiff', channel1)
# Out:
# C:\Users\bruni\AppData\Local\Temp\ipykernel_15048\2733705117.py:1: UserWarning: single_channel/channel1.tiff is a low contrast image
#   imsave('single_channel/channel1.tiff', channel1)

# %%
img_channel1 = imread('single_channel/channel1.tiff')

# %%
imshow(img_channel1)
